# %% [markdown]
# **1.Import neccessary libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# **2.Load and prepare your data**

# %%
x=np.array([[30],[40.5],[45],[56],[50],[70],[25],[10],[39],[90]])
y=np.array([0,0,1,1,1,1,0,0,1,1])

# %% [markdown]
# **3.Create and train logistic regression model**

# %%
model = LogisticRegression()
model.fit(x,y)
print("Intercept:",model.intercept_)
print("Coefficent:",model.coef_)
# Out:
# Intercept: [-14.29744009]
# Coefficent: [[0.36439927]]

# %% [markdown]
# **4.Make prediction**

# %%
x_test = np.array([60]) #define new data point
y_pred = model.predict([x_test]) #predict outcome
print("Predicted class:",y_pred)
# Out:
# Predicted class: [1]

# %% [markdown]
# **5.Visualization**

# %%
x_range = np.linspace(0,100,200).reshape(-1,1)
y_pred = model.predict_proba(x_range)[:,1]
plt.scatter(x,y, color= "brown", label="Data points")
plt.plot(x_range,y_pred,color = "blue", label="sigmoid curve")
plt.title("Logistic Regression(Loan Approval Prediction)")
plt.xlabel("Income (k)")
plt.ylabel("Probability of Loan approval")
plt.legend()
plt.grid(True)
plt.show()
